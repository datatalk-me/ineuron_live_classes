# %%
from flask import Flask,render_template,request,jsonify

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
flipcart_url = "https://www.flipkart.com/search?q="+"oneplus"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=oneplus'

# %%
response_website = urReq(flipcart_url)

# %%
data_flipcart = response_website.read()

# %%
beautifyed_html = bs(data_flipcart,"html.parser")

# %%
beautifyed_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox = beautifyed_html.find_all('div',{"class":"_1AtVbE col-12-12"})

# %%
bigbox[6].div.div.div.a['href']
# Out:
# '/oneplus-9-pro-5g-pine-green-256-gb/p/itm3892a7120e77b?pid=MOBGDM3FXQ2RWFGM&lid=LSTMOBGDM3FXQ2RWFGMEKA8QH&marketplace=FLIPKART&q=oneplus&store=search.flipkart.com&srno=s_1_17&otracker=search&fm=organic&iid=790c5b58-40ae-45f6-abce-eeeee4cc2db2.MOBGDM3FXQ2RWFGM.SEARCH&ppt=None&ppn=None&ssid=unh74rjv400000001661594876002&qH=43780d550576947f'

# %%
product6 = flipcart_url + bigbox[6].div.div.div.a['href']

# %%
import requests

# %%
product66 = requests.get(product6)

# %%
product6
# Out:
# 'https://www.flipkart.com/search?q=oneplus/oneplus-9-pro-5g-pine-green-256-gb/p/itm3892a7120e77b?pid=MOBGDM3FXQ2RWFGM&lid=LSTMOBGDM3FXQ2RWFGMEKA8QH&marketplace=FLIPKART&q=oneplus&store=search.flipkart.com&srno=s_1_17&otracker=search&fm=organic&iid=790c5b58-40ae-45f6-abce-eeeee4cc2db2.MOBGDM3FXQ2RWFGM.SEARCH&ppt=None&ppn=None&ssid=unh74rjv400000001661594876002&qH=43780d550576947f'

# %%
product66.encoding = 'utf-8'

# %%
type(product66)
# Out:
# requests.models.Response

# %%
product6_page = bs(product66.text,'html.parser')

# %%
all_review = product6_page.find_all('div',{'class':'_16PBlm'})

# %%
rating = all_review[5].div.div.div.div.text

# %%
rating
# Out:
# '5'

# %%
name = all_review[5].div.div.find_all('p',{'class':"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Anji Anji'

# %%
comment_header = all_review[5].div.div.div.p.text

# %%
comment_header
# Out:
# 'Terrific purchase'

# %%
all_review[5].div.div.find_all('div',{'class':""})[0].div.text
# Out:
# 'Super'

# %%
all_review[5].div.find_all('p',{"class":"_2sc7ZR"})[1].text
# Out:
# '25days ago'

# %%
# get the price
product6_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text
# Out:
# '₹49,990'

# %%
for i in all_review:
    pass
    # place all the things what you are going to print
